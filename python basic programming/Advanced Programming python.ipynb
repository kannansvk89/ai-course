# %%
fname = input("enter first name")
lname = input("enter last name")
companyname = "Gen AI"
print("Hello",fname,lname,"Welcome to the Gen AI Programe")
print("Hello {} welcome to the {}".format(fname+lname,companyname))
# Out:
# enter first name kannan
# enter last name N
# Hello kannan N Welcome to the Gen AI Programe
# Hello kannanN welcome to the Gen AI

# %%
gpa = abs(float(input("Enter your gpa")))
gpa
# Out:
# Enter your gpa -12
# 12.0

# %%
def myfunction(fname,lname):
    print("firstname",fname)
    print("lastname",lname)

myfunction(lname="navaneethan",fname="kannan")
# Out:
# firstname kannan
# lastname navaneethan

# %%
user_input = int(input("Enter the number"))
result = []
for i in range(1,user_input+1):
    if user_input%i ==0:
        result.append(i)

print(result)
# Out:
# Enter the number 20
# [1, 2, 4, 5, 10, 20]

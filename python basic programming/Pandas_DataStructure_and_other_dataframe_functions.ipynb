# %% [markdown]
# # Pandas Data Structure
# ##### * One dimensional
# ##### * Two Dimensional
# ##### * Filtering & Selection & Sorting
# ##### * Handling Missing Data

# %%
import pandas as pd
pd.Series(data = [1,2,3,0.7])
data = {"name":["A","B"],"age":[34,56]}
data = [{"name":"kannan","age":23},{"name":"ABC","age":34}]
data_1 = pd.DataFrame(data)

# %%
data_1.sort_values(by="name")
# Out:
#      name  age
# 1     ABC   34
# 0  kannan   23

# %%
#euro_match = pd.read_csv("football_team.csv",index_col="Team") this is used to put our own rather default index 0 , 1, 2  
euro_match = pd.read_csv("football_team.csv")
euro_match
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
pd.set_option('display.max_columns', None)
euro_match
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %% [markdown]
# # Data filtering and data frame functions

# %%
#Data filtering
red_card_teams = filtered_data[filtered_data["Red Cards"] > 0]

print(red_card_teams)
# Out:
#                    Team  Goals  Yellow Cards  Red Cards
# 6                Greece      5             9          1
# 9                Poland      2             7          1
# 11  Republic of Ireland      1             6          1

# %%
filtered_data.dtypes
# Out:
# Team            object
# Goals            int64
# Yellow Cards     int64
# Red Cards        int64
# dtype: object

# %% [markdown]
# ### Employee details handling missing data

# %%
employee = pd.read_csv("employee.csv")

# %%
#it will return where nan is exist rest FASE
#isnotnull is opposite to isnull
employee.isnull()
# Out:
#     Name    Age  Department  Salary  Join_Date
# 0  False  False       False   False      False
# 1  False  False       False    True      False
# 2  False   True       False   False      False
# 3  False  False       False   False      False
# 4  False  False       False   False      False
# 5  False  False       False   False      False
# 6   True  False       False   False      False
# 7  False  False       False    True      False

# %%
employee.isnull().sum()
# Out:
# Name          1
# Age           1
# Department    0
# Salary        2
# Join_Date     0
# dtype: int64

# %%
employee
# Out:
#       Name   Age Department   Salary   Join_Date
# 0   Rajesh  29.0        Ops  60000.0  21-05-2023
# 1    Nasir  31.0    IT Tech      NaN  12-11-2020
# 2  Mathiew   NaN    Support  58000.0  15-01-2025
# 3  Gilbert  29.0        Ops  60000.0  21-05-2021
# 4    Kevin  28.0    Support  61000.0  30-07-2024
# 5    Navin  35.0    Support  72000.0  19-08-2023
# 6      NaN  40.0         IT  64000.0  10-09-2022
# 7    Nasir  31.0    IT Tech      NaN  12-11-2020

# %%
#Remove Duplicates
employee.drop_duplicates(subset=["Name"],inplace=True)
#pd.set_option("display.max_rows", None)
employee
# Out:
#       Name   Age Department   Salary   Join_Date
# 0   Rajesh  29.0        Ops  60000.0  21-05-2023
# 1    Nasir  31.0    IT Tech      NaN  12-11-2020
# 2  Mathiew   NaN    Support  58000.0  15-01-2025
# 3  Gilbert  29.0        Ops  60000.0  21-05-2021
# 4    Kevin  28.0    Support  61000.0  30-07-2024
# 5    Navin  35.0    Support  72000.0  19-08-2023
# 6      NaN  40.0         IT  64000.0  10-09-2022

# %% [markdown]
# ### Update value in pandas dataframe using .loc[]

# %%
#wherever salary has nan put 60000 if the age is 31 in IT Tech
employee[(employee["Department"]=='IT Tech') & (employee["Age"]==31.0)]
employee.loc[(employee["Department"].isin(["IT", "Tech"])) & (employee["Age"]==31.0),"Salary"] = 60000
employee
# Out:
#       Name   Age Department   Salary   Join_Date
# 0   Rajesh  29.0        Ops  60000.0  21-05-2023
# 1    Nasir  31.0    IT Tech  60000.0  12-11-2020
# 2  Mathiew   NaN    Support  58000.0  15-01-2025
# 3  Gilbert  29.0        Ops  60000.0  21-05-2021
# 4    Kevin  28.0    Support  61000.0  30-07-2024
# 5    Navin  35.0    Support  72000.0  19-08-2023
# 6      NaN  40.0         IT  64000.0  10-09-2022

# %%
#Select multiple column
employee[["Name","Age"]]
# Out:
#       Name   Age
# 0   Rajesh  29.0
# 1    Nasir  31.0
# 2  Mathiew   NaN
# 3  Gilbert  29.0
# 4    Kevin  28.0
# 5    Navin  35.0
# 6      NaN  40.0

# %%
#indexing row and col
d = employee.loc[[0,1]]["Name"]
print(d)
# Out:
# 0    Rajesh
# 1     Nasir
# Name: Name, dtype: object

# %%
#index row and col using iloc
d = employee.iloc[0]["Name"]
print(d)
# Out:
# Rajesh

# %%
#fillna - PUT 0 whereeer nan is exist
employee.fillna("NA")
# Out:
#       Name   Age Department   Salary   Join_Date
# 0   Rajesh  29.0        Ops  60000.0  21-05-2023
# 1    Nasir  31.0    IT Tech  60000.0  12-11-2020
# 2  Mathiew    NA    Support  58000.0  15-01-2025
# 3  Gilbert  29.0        Ops  60000.0  21-05-2021
# 4    Kevin  28.0    Support  61000.0  30-07-2024
# 5    Navin  35.0    Support  72000.0  19-08-2023
# 6       NA  40.0         IT  64000.0  10-09-2022

# %%
#Dropna
employee.dropna()
# Out:
#       Name   Age Department   Salary   Join_Date
# 0   Rajesh  29.0        Ops  60000.0  21-05-2023
# 1    Nasir  31.0    IT Tech  60000.0  12-11-2020
# 3  Gilbert  29.0        Ops  60000.0  21-05-2021
# 4    Kevin  28.0    Support  61000.0  30-07-2024
# 5    Navin  35.0    Support  72000.0  19-08-2023

# %%
# Iterate rows
dict = {'name':["aparna", "pankaj", "sudhir", "Geeku"],
        'degree': ["MBA", "BCA", "M.Tech", "MBA"],
        'score':[90, 40, 80, 98]}
 
df = pd.DataFrame(dict)

for i, j in df.iterrows():
    print(i, j)
    print()
# Out:
# 0 name      aparna
# degree       MBA
# score         90
# Name: 0, dtype: object
#
# 1 name      pankaj
# degree       BCA
# score         40
# Name: 1, dtype: object
#
# 2 name      sudhir
# degree    M.Tech
# score         80
# Name: 2, dtype: object
#
# 3 name      Geeku
# degree      MBA
# score        98
# Name: 3, dtype: object

# %%
employee.loc[[0,1],"Salary"]
# Out:
# 0    60000.0
# 1    60000.0
# Name: Salary, dtype: float64

# %%
#Iterating columnwise
dict = {'name':["aparna", "pankaj", "sudhir", "Geeku"],
        'degree': ["MBA", "BCA", "M.Tech", "MBA"],
        'score':[90, 40, 80, 98]}
  
df = pd.DataFrame(dict)
 
print(df)
#columns = list(df)
 
#for i in columns:
 #   print (df[i][2])
# Out:
#      name  degree  score
# 0  aparna     MBA     90
# 1  pankaj     BCA     40
# 2  sudhir  M.Tech     80
# 3   Geeku     MBA     98

# %%
#insert
df = pd.DataFrame({'A': [1, 2], 'B': [3, 4]})
df.insert(2, 'C', [5, 6])

print(df)
# Out:
#    A  B  C
# 0  1  3  5
# 1  2  4  6

# %%
#unique
employee["Age"]
# Out:
# 0    29.0
# 1    31.0
# 2     NaN
# 3    29.0
# 4    28.0
# 5    35.0
# 6    40.0
# Name: Age, dtype: float64

# %%
#nunique - it tells how unique column or row in a give datafrom , by default column
employee.nunique(axis = 1)
# Out:
# 0    5
# 1    5
# 2    4
# 3    5
# 4    5
# 5    5
# 6    4
# dtype: int64

# %%
#count unique value in columns
# Count unique values in the 'Name' column
employee['Name'].nunique()
# Out:
# 6

# %%
#value counts, while group by count the value
employee.groupby('Age')['Name'].value_counts()
# Out:
# Age   Name
# 28.0  Kevin      1
# 29.0  Gilbert    1
#       Rajesh     1
# 31.0  Nasir      1
# 35.0  Navin      1
# Name: count, dtype: int64

# %%
#Column attribute returns the column name
df = pd.DataFrame({
    "A": [12, 4, 5, None, 1],
    "B": [7, 2, 54, 3, None],
    "C": [20, 16, 11, 3, 8],
    "D": [14, 3, None, 2, 6] })

idx = ['Row_1', 'Row_2', 'Row_3', 'Row_4', 'Row_5']
df.index = idx

res = df.columns

print("\n Name of Columns of Pandas DataFrame")
print(res)
# Out:
#  Name of Columns of Pandas DataFrame
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
#astype
df = pd.DataFrame({'A': ['1', '2'], 'B': ['3.5', '4.5']})

res = df.astype({'A': int, 'B': float})
print(res)
print(res.dtypes)
# Out:
#    A    B
# 0  1  3.5
# 1  2  4.5
# A      int64
# B    float64
# dtype: object

# %%
#Drop
employee.drop(1)
# Out:
#       Name   Age Department   Salary   Join_Date
# 0   Rajesh  29.0        Ops  60000.0  21-05-2023
# 2  Mathiew   NaN    Support  58000.0  15-01-2025
# 3  Gilbert  29.0        Ops  60000.0  21-05-2021
# 4    Kevin  28.0    Support  61000.0  30-07-2024
# 5    Navin  35.0    Support  72000.0  19-08-2023
# 6      NaN  40.0         IT  64000.0  10-09-2022

# %%
#To drop column
employee.drop("Name",axis=1)
# Out:
#     Age Department   Salary   Join_Date
# 0  29.0        Ops  60000.0  21-05-2023
# 1  31.0    IT Tech  60000.0  12-11-2020
# 2   NaN    Support  58000.0  15-01-2025
# 3  29.0        Ops  60000.0  21-05-2021
# 4  28.0    Support  61000.0  30-07-2024
# 5  35.0    Support  72000.0  19-08-2023
# 6  40.0         IT  64000.0  10-09-2022

# %%
#nlargest - may be used nth highest value, Simlarly for nsmallest
employee.nlargest(7,"Salary").sort_values("Salary",ascending=True).head(1)
# Out:
#       Name  Age Department   Salary   Join_Date
# 2  Mathiew  NaN    Support  58000.0  15-01-2025
